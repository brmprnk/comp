# %%
import pandas as pd

# %%
bed = pd.read_csv("beds/biomart.bed", sep="\t", header=None)
bed.columns = ["chrom", "start", "end", "name", "strand", "gc"]
bed["start"] = bed["start"] - 500
bed["end"] = bed["end"] + 500
bed.to_csv("beds/biomart.bed", sep="\t", header=False, index=False)
